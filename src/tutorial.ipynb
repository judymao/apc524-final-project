# %% [markdown]
# ### Import Momentum strategy and Backtest class

# %%
from tradestrat import Momentum, Backtest

# %% [markdown]
# ### Create a list of stocks that we'd like to include in our portfolio

# %%
stocks = ["A", "AAPL", "ABC", "ABMD", "ABT", "ADBE", "ADI", "ADM", "ADP", "ADSK", "AEE", "AEP"]

# %% [markdown]
# ### Initialize Momentum strategy class

# %%
momentum = Momentum(stocks)

# %% [markdown]
# ### Get weights from Momentum strategy

# %%
weights = momentum.get_weights()

# %%
weights
# Out:
#                    A      AAPL       ABC      ABMD       ABT      ADBE  \
# Date
# 2000-01-03  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2000-01-04  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2000-01-05  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2000-01-06  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2000-01-07  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-25  0.000000  0.000000  0.500000  0.000000  0.000000 -1.000000
# 2022-10-26  0.000000  0.000000  0.500000  0.000000  0.000000 -1.000000
# 2022-10-27  0.000000  0.000000  0.500000  0.000000  0.000000 -1.000000
# 2022-10-28  0.000000  0.000000  0.500000  0.000000  0.000000 -1.000000
# 2022-10-31  0.000000  0.000000  0.500000  0.000000  0.000000 -1.000000
#
#                  ADI       ADM       ADP      ADSK       AEE       AEP
# Date
# 2000-01-03 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667
# 2000-01-04 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667
# 2000-01-05 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667
# 2000-01-06 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667
# 2000-01-07 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667 -0.166667
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-25  0.000000  0.500000  0.000000  0.000000  0.000000  0.000000
# 2022-10-26  0.000000  0.500000  0.000000  0.000000  0.000000  0.000000
# 2022-10-27  0.000000  0.500000  0.000000  0.000000  0.000000  0.000000
# 2022-10-28  0.000000  0.500000  0.000000  0.000000  0.000000  0.000000
# 2022-10-31  0.000000  0.500000  0.000000  0.000000  0.000000  0.000000
#
# [5745 rows x 12 columns]

# %% [markdown]
# ### Initialize Backtest class

# %%
backtest = Backtest(momentum)

# %% [markdown]
# ### Get daily returns -- can get cumulative or non-cumulative returns

# %%
backtest.get_return(cumulative=True)
# Out:
# array([ 0.        , -0.00446067, -0.00362991, ...,  3.3396472 ,
#         3.54775322,  3.47963788])

# %%
backtest.get_return(cumulative=False)
# Out:
# array([ 0.        , -0.00446067,  0.00083448, ..., -0.01815743,
#         0.04795459, -0.0149778 ])

# %% [markdown]
# ### Get annualized returns, volatilities, and downside volatilities

# %%
backtest.get_annualized_return()
# Out:
# 0.07462746401890508

# %%
backtest.get_annualized_vol()
# Out:
# 0.11133594854589578

# %%
backtest.get_annualized_downside_vol()
# Out:
# 0.07064043074927395

# %% [markdown]
# ### Get Sharpe and Sortino ratios

# %%
backtest.get_sharpe(rf_rate = 0.02)
# Out:
# 0.4906543190440068

# %%
backtest.get_rolling_sharpe(rf_rate = 0.02, lookback = 10)
# Out:
# array([ 2.32544426,  5.13557373,  4.34569853, ..., 18.76996841,
#         2.92121428, 28.74784741])

# %%
backtest.get_sortino(rf_rate = 0.02)
# Out:
# 0.7733172552811272

# %%
backtest.get_rolling_sortino(rf_rate = 0.02, lookback = 10)
# Out:
# array([ 2.32544426,  5.13557373,  4.34569853, ..., 20.51628842,
#         2.97097798, 40.23610421])

# %% [markdown]
# ### Get maximum drawdown

# %%
backtest.get_max_drawdown()
# Out:
# 1.0113260331886542

# %% [markdown]
# ### Get maximum consecutive positives/negatives

# %%
backtest.get_max_consecutive_positive()
# Out:
# 12

# %%
backtest.get_max_consecutive_negative()
# Out:
# 10

# %% [markdown]
# ### Get underwater times

# %%
backtest.get_max_underwater_time(threshold_days = 20)
# Out:
# 19

# %%
backtest.get_avg_underwater_time(threshold_days = 20)
# Out:
# 3.085858585858586

# %% [markdown]
# ### Make plots

# %%
backtest.plot_returns()

# %%
backtest.plot_sharpe(rf_rate = 0.02, lookback = 10)

# %%
backtest.plot_sortino(rf_rate = 0.02, lookback = 10)
